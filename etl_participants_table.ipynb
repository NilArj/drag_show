# %% [markdown]
# # Data Extraction

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#get the web page
url = "https://es.wikipedia.org/wiki/La_M%C3%A1s_Draga_(M%C3%A9xico)"

# %%
# Extract data from all seasons of the show
html = pd.read_html(url)
drags_s2 = html[6]
drags_s3 = html[9]
drags_s4 = html[12]
drags_s5 = html[15]

# %% [markdown]
# # Data Transformation

# %%
# add the column season and the number to each table
drags_s2["Temporada"] = "2"
drags_s3["Temporada"] = "3"
drags_s4["Temporada"] = "4"
drags_s5["Temporada"] = "5"

# %%
# create the data frame with all seasons of the show 
df_drags = pd.concat([drags_s2,drags_s3, drags_s4, drags_s5])
df_drags
# Out:
#    Lugar         Participante     Participante.1  \
# 0     1º           Alexis 3XL         Alexis 3XL
# 1     2º       Sophia Jiménez     Sophia Jiménez
# 2     3º             Gvajardo           Gvajardo
# 3     4º             Job Star           Job Star
# 4     5º           Soro Nasty         Soro Nasty
# 5     6º       Amelia Waldorf     Amelia Waldorf
# 6     7º       Red Rabbit Duo          Gala Varo
# 7     7º       Red Rabbit Duo       Génesis Faux
# 8     8º         Leandra Rose       Leandra Rose
# 9     9º    Nina de la Fuente  Nina de la Fuente
# 0     1º          Aviesc Who?                NaN
# 1     2º       Madison Basrey                NaN
# 2     3º        Raga Diamante                NaN
# 3     4º           Rudy Reyes                NaN
# 4     5º            Mista Boo                NaN
# 5     6º           Memo Reyri                NaN
# 6     7º         Regina Bronx                NaN
# 7     8º          Iviza Lioza                NaN
# 8     9º         Luna Lansman                NaN
# 9    10º               Wynter                NaN
# 10   11º             Huntyy B                NaN
# 11   12º            StupiDrag                NaN
# 12   13º         Yayoi Bowery                NaN
# 0     1°           Rebel Mörk                NaN
# 1     2°               C-Pher                NaN
# 2     3°              Iris XC                NaN
# 3     4°   Elektra Vandergeld                NaN
# 4     5°            Leexa Fox                NaN
# 5     6°        La Morra Lisa                NaN
# 6     7°          Lupita Kush                NaN
# 7     8°            Georgiana                NaN
# 8     9°            Vera Cruz                NaN
# 9    10°             Tiresias                NaN
# 10   12°            Paper Cut                NaN
# 11   11°               Sirena                NaN
# 12   13°      La Carrera Mami                NaN
# 13   14°       Aurora Wonders                NaN
# 0     1°           Fifí Estah                NaN
# 1     2°            Paper Cut                NaN
# 2     3°       Liza Zan Zuzzi                NaN
# 3     4°       Hidden Mistake                NaN
# 4     5°          Santa Lucía                NaN
# 5     6°         Gretha White                NaN
# 6     7°        Peke Balderas                NaN
# 7     8°      Aisha Dollkills                NaN
# 8     9°           Light King                NaN
# 9    10°            Huma Kyle                NaN
# 10   11°  Isabella y Catalina                NaN
# 11   12°           Deseos Fab                NaN
#
#                              Nombre       Lugar de residencia  \
# 0                      Itzel Moreno     Matamoros, Tamaulipas
# 1                 Guillermo Jiménez         Guadalajara, Jal.
# 2                    Pablo Guajardo            Monterrey, NL.
# 3       José Job Carrisalez Sánchez           Saltillo, Coah.
# 4                         Luis Soro           Monterrey, N.L.
# 5             Amelia Chávez Quezada          Ciudad de México
# 6                 Jesús Meza Arroyo         Guadalajara, Jal.
# 7                        Hugo López         Guadalajara, Jal.
# 8                  Joshua Ontiveros            Progreso, Yuc.
# 9   Vicente Alejandro Arias Fuentes          Ciudad de México
# 0        Luis Jessy Ávila Escamilla         Guadalajara, Jal.
# 1           Madison Basoria Herrera         Guadalajara, Jal.
# 2      Yusef Alejandro Alcalá Tinah              Mérida, Yuc.
# 3      Rodolfo Isaac Renovato Reyes           Monterrey, N.L.
# 4             Alejandro Garza Chapa           Monterrey, N.L.
# 5           Guillermo Reyes del Río          Ciudad de México
# 6       Luis Arnulfo Peña Gutiérrez      Aguascalientes, Ags.
# 7        Franko Rafael Ayala Pulido          Ciudad de México
# 8          Abraham Sinue Luna Ortiz          Ciudad de México
# 9       Luis Enrique Cedillo Lozano           Monterrey, N.L.
# 10              Edgar Fenty de la O      Ciudad Juárez, Chih.
# 11                 José Luis Favila       Gómez Palacio, Dgo.
# 12               Jorge Amhed Kahuam          Ciudad de México
# 0        Alfredo Guillermo Figueroa           Monterrey, N.L.
# 1                     Felipe Rivera        Antofagasta, Chile
# 2                    Xavier Carreto          Chihuahua, Chih.
# 3                       Eseen Ortiz            Ensenada, B.C.
# 4                         Axel Díaz            Mexicali, B.C.
# 5                    Roel Maldonado           Zacatecas, Zac.
# 6                    Brian Villegas         Guadalajara, Jal.
# 7                           Georgie           Monterrey, N.L.
# 8                   Brian Escamilla           Monterrey, N.L.
# 9                     Tabris Berges          Ciudad de México
# 10                      Rafael León          Ciudad de México
# 11                    Gerardo Leija         Guadalajara, Jal.
# 12                    Henry Carrera  Acapulco de Juárez, Gro.
# 13                   Carlos Velasco          Ciudad de México
# 0                      Ángel García    Lázaro Cárdenas, Mich.
# 1                       Rafael León          Ciudad De México
# 2                   Edgardo Cabrera  Acapulco de Juárez, Gro.
# 3                     Maddie Jamett           Santiago, Chile
# 4                   Emilio González  Ciudad Neza, Edo de Méx.
# 5                      Walter Duque        Medellín, Colombia
# 6                   Daniel Balderas           Monterrey, N.L.
# 7                    Andrey Miranda      San José, Costa Rica
# 8                       Juan Correa            Cali, Colombia
# 9                       Tony Porras          Chihuahua, Chih.
# 10                    Alex y Carlos     San Diego, California
# 11                   Alexis Vázquez          Ciudad de México
#
#                                   Edad                Selección  \
# 0        7 de agosto de 1995 (28 años)           Audiciones MTY
# 1       2 de febrero de 1992 (31 años)           Audiciones GDL
# 2      14 de octubre de 1993 (29 años)              Secretísima
# 3        30 de marzo de 1989 (34 años)           Audiciones MTY
# 4        16 de marzo de 1990 (33 años)             Pase directo
# 5      12 de febrero de 1998 (25 años)              Secretisima
# 6          1 de mayo de 1989 (34 años)           Audiciones GDL
# 7                              31 años           Audiciones GDL
# 8      30 de octubre de 1994 (28 años)           Audiciones MÉR
# 9         2 de julio de 1992 (31 años)              Secretísima
# 0         25 de mayo de 1986 (37 años)           Audiciones GDL
# 1        21 de abril de 1994 (29 años)           Audiciones GDL
# 2      23 de octubre de 1987 (35 años)              Secretisima
# 3         4 de enero de 1995 (28 años)           Audiciones MTY
# 4       06 de junio de 1866 (157 años)           Audiciones MTY
# 5        14 de marzo de 1984 (39 años)              Secretisimo
# 6    27 de diciembre de 1998 (24 años)              Secretisima
# 7         8 de abril de 1993 (30 años)          Audiciones CDMX
# 8       26 de agosto de 1987 (36 años)          Audiciones CDMX
# 9        26 de julio de 1994 (29 años)           Audiciones MTY
# 10        16 de mayo de 1993 (30 años)        Audiciones CD.JRZ
# 11  16 de septiembre de 1990 (33 años)              Secretisima
# 12   28 de noviembre de 1987 (35 años)              Secretisima
# 0                              26 años               Audiciones
# 1                              30 años      Secreta de secretas
# 2                              26 años               Audiciones
# 3                              24 años               Audiciones
# 4                              20 años               Audiciones
# 5                              28 años               Audiciones
# 6                              23 años               Audiciones
# 7                              43 años            La más Votada
# 8                              24 años  Secreta de las secretas
# 9                              33 años               Audiciones
# 10                             23 años               Audiciones
# 11                             30 años               Audiciones
# 12                             35 años               Audiciones
# 13                             32 años  Secreta de las secretas
# 0                              28 años   Ganadora de Audiciones
# 1                              25 años              Secretísimo
# 2                              30 años            La Más Votada
# 3                              25 años               Audiciones
# 4                              27 años               Audiciones
# 5                              29 años               Audiciones
# 6                              30 años               Audiciones
# 7                              21 años               Audiciones
# 8                              26 años              Secretísima
# 9                              29 años               Audiciones
# 10                             25 años             Secretísimas
# 11                             24 años            La más Votada
#
#     Retos ganados          Resultado Temporada
# 0               2           Ganadora         2
# 1               3         Finalistas         2
# 2               1         Finalistas         2
# 3               0       6ª eliminada         2
# 4               0       5ª eliminada         2
# 5               0       4ª eliminada         2
# 6               1      3ª eliminadas         2
# 7               1      3ª eliminadas         2
# 8               0       2ª eliminada         2
# 9               0       1ª eliminada         2
# 0               1      Ganadora[11]​         3
# 1               2         Finalistas         3
# 2               3         Finalistas         3
# 3               1         Finalistas         3
# 4               1    8ª/9ª eliminada         3
# 5               1    8ª/9ª eliminada         3
# 6               1       7ª eliminada         3
# 7               0       6ª eliminada         3
# 8               0       5ª eliminada         3
# 9               0       4ª eliminada         3
# 10              0       3ª eliminada         3
# 11              0       2ª eliminada         3
# 12              0       1ª eliminada         3
# 0               1           Ganadora         4
# 1               3          Finalista         4
# 2               0          Finalista         4
# 3               2          Finalista         4
# 4               1   9ª/10ª eliminada         4
# 5               0   9ª/10ª eliminada         4
# 6               0       8ª eliminada         4
# 7               1    6ª/7ª eliminada         4
# 8               1    6ª/7ª eliminada         4
# 9               0       5ª eliminada         4
# 10              1       4° eliminado         4
# 11              1       3ª eliminada         4
# 12              0       2ª eliminada         4
# 13              0       1ª eliminada         4
# 0               3           Ganadora         5
# 1               2          Finalista         5
# 2               1          Finalista         5
# 3               1  Finalista secreta         5
# 4               2           Abandona         5
# 5               1       6ª Eliminada         5
# 6               1       5ª Eliminada         5
# 7               0       4ª Eliminada         5
# 8               0           Abandona         5
# 9               0       3ª Eliminada         5
# 10              0       2ª Eliminada         5
# 11              0       1ª Eliminada         5

# %%
df_drags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Lugar                49 non-null     object
#  1   Participante         49 non-null     object
#  2   Participante.1       10 non-null     object
#  3   Nombre               49 non-null     object
#  4   Lugar de residencia  49 non-null     object
#  5   Edad                 49 non-null     object
#  6   Selección            49 non-null     object
#  7   Retos ganados        49 non-null     int64
#  8   Resultado            49 non-null     object
#  9   Temporada            49 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 4.2+ KB

# %%
# cleaning the data
df_drags["Edad"] = df_drags["Edad"].astype(str)
pattern = r'(\d+)\s*años'
df_drags["Edad"] = df_drags["Edad"].str.extract(pattern, expand=False)
print(df_drags["Edad"])
# Out:
# 0      28
# 1      31
# 2      29
# 3      34
# 4      33
# 5      25
# 6      34
# 7      31
# 8      28
# 9      31
# 0      37
# 1      29
# 2      35
# 3      28
# 4     157
# 5      39
# 6      24
# 7      30
# 8      36
# 9      29
# 10     30
# 11     33
# 12     35
# 0      26
# 1      30
# 2      26
# 3      24
# 4      20
# 5      28
# 6      23
# 7      43
# 8      24
# 9      33
# 10     23
# 11     30
# 12     35
# 13     32
# 0      28
# 1      25
# 2      30
# 3      25
# 4      27
# 5      29
# 6      30
# 7      21
# 8      26
# 9      29
# 10     25
# 11     24
# Name: Edad, dtype: object

# %%
df_drags["Edad"] = df_drags["Edad"].astype(int)
df_drags["Temporada"] = df_drags["Temporada"].astype(int)
df_drags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Lugar                49 non-null     object
#  1   Participante         49 non-null     object
#  2   Participante.1       10 non-null     object
#  3   Nombre               49 non-null     object
#  4   Lugar de residencia  49 non-null     object
#  5   Edad                 49 non-null     int32
#  6   Selección            49 non-null     object
#  7   Retos ganados        49 non-null     int64
#  8   Resultado            49 non-null     object
#  9   Temporada            49 non-null     int32
# dtypes: int32(2), int64(1), object(7)
# memory usage: 3.8+ KB

# %%
df_drags["Retos ganados"] = df_drags["Retos ganados"].fillna(0).astype(int)
df_drags["Retos ganados"] = df_drags["Retos ganados"].astype(int)
df_drags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Lugar                49 non-null     object
#  1   Participante         49 non-null     object
#  2   Participante.1       10 non-null     object
#  3   Nombre               49 non-null     object
#  4   Lugar de residencia  49 non-null     object
#  5   Edad                 49 non-null     int32
#  6   Selección            49 non-null     object
#  7   Retos ganados        49 non-null     int32
#  8   Resultado            49 non-null     object
#  9   Temporada            49 non-null     int32
# dtypes: int32(3), object(7)
# memory usage: 3.6+ KB

# %%
df_drags["Participante.1"].isnull().sum()
# Out:
# 39

# %%
df_drags.drop("Participante.1", axis=1, inplace=True)

# %%
print(df_drags.columns)
# Out:
# Index(['Lugar', 'Participante', 'Nombre', 'Lugar de residencia', 'Edad',
#        'Selección', 'Retos ganados', 'Resultado', 'Temporada'],
#       dtype='object')

# %%
df_drags['Lugar'] = df_drags['Lugar'].astype(str).str.replace('[º°]', '', regex=True)

# %%
df_drags.head()
# Out:
#   Lugar    Participante                       Nombre    Lugar de residencia  \
# 0     1      Alexis 3XL                 Itzel Moreno  Matamoros, Tamaulipas
# 1     2  Sophia Jiménez            Guillermo Jiménez      Guadalajara, Jal.
# 2     3        Gvajardo               Pablo Guajardo         Monterrey, NL.
# 3     4        Job Star  José Job Carrisalez Sánchez        Saltillo, Coah.
# 4     5      Soro Nasty                    Luis Soro        Monterrey, N.L.
#
#    Edad       Selección  Retos ganados     Resultado  Temporada
# 0    28  Audiciones MTY              2      Ganadora          2
# 1    31  Audiciones GDL              3    Finalistas          2
# 2    29     Secretísima              1    Finalistas          2
# 3    34  Audiciones MTY              0  6ª eliminada          2
# 4    33    Pase directo              0  5ª eliminada          2

# %% [markdown]
# # Data Load

# %%
engine = create_engine("mysql+pymysql://root:NilArj_21@localhost:3306/project")

table_name = "la_mas_draga"

df_drags.to_sql(
    table_name,
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 49

# %%
engine.dispose()
